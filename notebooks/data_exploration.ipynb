# %%
# %pwd

# %%
# %cd ..

# %%
from src.data_preprocessing.explore_data import load_sample_images, explore_data_distribution

# %%
data_directory = "data\\raw"
load_sample_images(data_directory)
explore_data_distribution(data_directory)

# %%
from src.data_preprocessing.augment_data import augment_images

# %%
input_directory = "data\\processed"
output_directory = "data\\augmented"
augment_factor = 2
augment_images(input_directory, output_directory, augment_factor)
